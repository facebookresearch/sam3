# %% [markdown]
# # SAM3 Dense Tracking (MultiGPU)

# %% [markdown]
# ## 0. Prerequisites

# %% [markdown]
# #### Conda env
#
# In case there are any environment or dependency errors on FAIR-SC, you can **directly use Ronghang's FAIR-SC conda env via**
# ```
# conda activate /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3
# ```
# which contains all dependencies we need for this notebook.

# %% [markdown]
# #### GPU setup
#
# This notebook is expected to run on an **interactive slurm node with multiple (ideally 8) GPUs**. You can do the following to get an 8-GPU slurm session on FAIR-SC
# ```
# srun --mem=480g --nodes=1 --gres=gpu:8 --account=sam3 --qos=h200_sam3_high --time=160:00:00 --cpus-per-task=80 --pty /bin/bash -l
# ```
# and launch the Jupyter lab from there via
# ```
# conda activate /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3
# jupyter lab --port 8888 --ip 0.0.0.0 --no-browser
# ```
#
# Then, **forward the Jupyter lab port to your Meta laptop**:
# ```
# ssh <your-fair-sc-ssh-config> -fNL 8888:h200-241-207:8888
# ```
# where `8888` is the Jupyter lab port and `h200-241-207` is the interactive slurm node's hostname (**replace them with your actual port and slurm node hostname**).

# %%
!nvidia-smi
# Out:
# Sun Sep  7 17:38:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.05              Driver Version: 560.35.05      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H100 80GB HBM3          On  |   00000000:53:00.0 Off |                    0 |
# | N/A   27C    P0             68W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA H100 80GB HBM3          On  |   00000000:64:00.0 Off |                    0 |
# | N/A   29C    P0             67W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA H100 80GB HBM3          On  |   00000000:75:00.0 Off |                    0 |
# | N/A   27C    P0             68W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA H100 80GB HBM3          On  |   00000000:86:00.0 Off |                    0 |
# | N/A   30C    P0             67W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA H100 80GB HBM3          On  |   00000000:97:00.0 Off |                    0 |
# | N/A   30C    P0             68W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA H100 80GB HBM3          On  |   00000000:A8:00.0 Off |                    0 |
# | N/A   27C    P0             66W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   6  NVIDIA H100 80GB HBM3          On  |   00000000:B9:00.0 Off |                    0 |
# | N/A   28C    P0             69W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   7  NVIDIA H100 80GB HBM3          On  |   00000000:CA:00.0 Off |                    0 |
# | N/A   28C    P0             67W /  700W |       1MiB /  81559MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 1. Setup

# %%
# GPU IDs to use for this notebook -- to use a single GPU, set it to
GPUS_TO_USE = [0, 1, 2, 3, 4, 5, 6, 7]


checkpoint_file = "/checkpoint/sam3/haithamkhedr/checkpoints/sam3_dense/prod_v12_sam2_internal_shared_dth0.5_newdet0.7_assth0.1_nms0.1.pt"
bpe_path = "/home/kalyanv/sam3/assets/bpe_simple_vocab_16e6.txt.gz"

# %%
import os
import random
import sys
from glob import glob

# sys.path.insert(0, "/home/kalyanv/onevision")
# sys.path.insert(0, "/home/kalyanv/onevision/projects")
# os.environ["DVC_LOCK"] = "/home/kalyanv/onevision/projects/onevision/dvc.lock"

# set the GPUs to use via "CUDA_VISIBLE_DEVICES"
assert all(isinstance(i, int) for i in GPUS_TO_USE)
assert GPUS_TO_USE == sorted(set(GPUS_TO_USE))
os.environ["CUDA_VISIBLE_DEVICES"] = ",".join(str(i) for i in GPUS_TO_USE)

# !!! this line needs to be *after* setting "CUDA_VISIBLE_DEVICES" but *before* any torch import !!!
# import webdemo.ta.models.sam3_model_multigpu
from sam3.model.sam3_model_web import Sam3Model

# the `Sam3ModelMultiGPU` class will spawn worker processes and set up an NCCL process group
# model_wrapper = webdemo.ta.models.sam3_model.Sam3Model(
#     config_file=config_file,
#     checkpoint_file=checkpoint_file,
#     hydra_overrides=hydra_overrides,
#     strict_state_dict_loading=True,
# )

from sam3.sam3_dense_tracking_builder import build_sam3_dense_tracking_model
model_wrapper = Sam3Model(
    model = build_sam3_dense_tracking_model(bpe_path=bpe_path, checkpoint_path=checkpoint_file).cuda().eval(),


    strict_state_dict_loading=True,
)
# Out:
# INFO:root:Using points (sampled from masks) as inputs
# INFO:sam3.model.sam3_dense_shared_multigpu:`setting max_num_objects` to 128 -- creating num_obj_for_compile=128 objects for torch.compile cache

# %%
# cfg = model_wrapper.cfg
# # cfg['trainer']['model']
# from omegaconf import OmegaConf

# # print(cfg.trainer.model)
# print(OmegaConf.to_yaml(cfg.trainer.model))

# %% [markdown]
# ### Visualization utils

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import pprint
import cv2
import subprocess
import torch
from matplotlib.colors import to_rgb
from matplotlib.patches import Rectangle
from PIL import Image
from skimage.color import rgb2lab, lab2rgb
from sklearn.cluster import KMeans
from tqdm import tqdm
from sam3.model.data_misc import recursive_to, interpolate
from torchvision.ops import masks_to_boxes


def generate_colors(n_colors=256, n_samples=5000):
    # Step 1: Random RGB samples
    np.random.seed(42)
    rgb = np.random.rand(n_samples, 3)
    # Step 2: Convert to LAB for perceptual uniformity
    print(f"Converting {n_samples} RGB samples to LAB color space...")
    lab = rgb2lab(rgb.reshape(1, -1, 3)).reshape(-1, 3)
    print("Conversion to LAB complete.")
    # Step 3: k-means clustering in LAB
    kmeans = KMeans(n_clusters=n_colors, n_init=10)
    print(f"Fitting KMeans with {n_colors} clusters on {n_samples} samples...")
    kmeans.fit(lab)
    print("KMeans fitting complete.")
    centers_lab = kmeans.cluster_centers_
    # Step 4: Convert LAB back to RGB
    colors_rgb = lab2rgb(centers_lab.reshape(1, -1, 3)).reshape(-1, 3)
    colors_rgb = np.clip(colors_rgb, 0, 1)
    return colors_rgb


COLORS = generate_colors(n_colors=128, n_samples=5000)


def show_img_tensor(img_batch, vis_img_idx=0):
    MEAN_IMG = np.array([0.485, 0.456, 0.406])
    STD_IMG = np.array([0.229, 0.224, 0.225])
    im_tensor = img_batch[vis_img_idx].detach().cpu()
    assert im_tensor.dim() == 3
    im_tensor = im_tensor.numpy().transpose((1, 2, 0))
    im_tensor = (im_tensor * STD_IMG) + MEAN_IMG
    im_tensor = np.clip(im_tensor, 0, 1)
    plt.imshow(im_tensor)


def show_points_with_labels(coords, labels, ax=None, marker_size=200):
    if ax is None:
        ax = plt.gca()
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color="green", marker="*", s=marker_size, edgecolor="white", linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color="red", marker="*", s=marker_size, edgecolor="white", linewidth=1.25)


def plot_bbox(
    img_height,
    img_width,
    box,
    box_format="XYXY",
    relative_coords=True,
    color="r",
    linestyle="solid",
    text=None,
    ax=None,
):
    if box_format == "XYXY":
        x, y, x2, y2 = box
        w = x2 - x
        h = y2 - y
    elif box_format == "XYWH":
        x, y, w, h = box
    elif box_format == "CxCyWH":
        cx, cy, w, h = box
        x = cx - w / 2
        y = cy - h / 2
    else:
        raise RuntimeError(f"Invalid box_format {box_format}")

    if relative_coords:
        x *= img_width
        w *= img_width
        y *= img_height
        h *= img_height

    if ax is None:
        ax = plt.gca()
    rect = patches.Rectangle(
        (x, y), w, h, linewidth=1.5, edgecolor=color, facecolor="none", linestyle=linestyle,
    )
    ax.add_patch(rect)
    if text is not None:
        facecolor = "w"
        ax.text(
            x, y - 5, text, color=color, weight="bold", fontsize=8,
            bbox={"facecolor": facecolor, "alpha": 0.75, "pad": 2},
        )


def plot_mask(mask, color="r", ax=None):
    im_h, im_w = mask.shape
    mask_img = np.zeros((im_h, im_w, 4), dtype=np.float32)
    mask_img[..., :3] = to_rgb(color)
    mask_img[..., 3] = mask * 0.5
    # Use the provided ax or the current axis
    if ax is None:
        ax = plt.gca()
    ax.imshow(mask_img)


def normalize_bbox(bbox_xyxy, img_w, img_h):
    bbox_xyxy[0], bbox_xyxy[2] = bbox_xyxy[0] / img_w, bbox_xyxy[2] / img_w
    bbox_xyxy[1], bbox_xyxy[3] = bbox_xyxy[1] / img_h, bbox_xyxy[3] / img_h
    return bbox_xyxy

def visualize_frame_output(frame_idx, image_files, outputs, figsize=(12, 8)):
    plt.figure(figsize=figsize)
    plt.title(f"frame {frame_idx}")
    img = plt.imread(image_files[frame_idx])
    img_H, img_W, _ = img.shape
    plt.imshow(img)
    for i in range(len(outputs["out_probs"])):
        box_xywh = outputs["out_boxes_xywh"][i]
        prob = outputs["out_probs"][i]
        obj_id = outputs["out_obj_ids"][i]
        binary_mask = outputs["out_binary_masks"][i]
        color = COLORS[obj_id % len(COLORS)]
        plot_bbox(img_H, img_W, box_xywh, text=f"(id={obj_id}, {prob=:.2f})", box_format="XYWH", color=color)
        plot_mask(binary_mask, color=color)


def visualize_formatted_frame_output(frame_idx, image_files, outputs_list, titles=None, points_list=None, points_labels_list=None, figsize=(12, 8)):
    """Visualize up to three sets of segmentation masks on a video frame.

    outputs_list: List of {frame_idx: {obj_id: mask_tensor}}
    titles: List of titles for each set of outputs_list
    """
    num_outputs = len(outputs_list)
    if titles is None:
        titles = [f"Set {i+1}" for i in range(num_outputs)]
    assert len(titles) == num_outputs, "length of `titles` should match that of `outputs_list` if not None."

    fig, axes = plt.subplots(1, num_outputs, figsize=figsize)
    if num_outputs == 1:
        axes = [axes]  # Make it iterable
    img = plt.imread(image_files[frame_idx])
    img_H, img_W, _ = img.shape
    for idx in range(num_outputs):
        ax, outputs_set, ax_title = axes[idx], outputs_list[idx], titles[idx]
        ax.set_title(f"Frame {frame_idx} - {ax_title}")
        ax.imshow(img)
        _outputs = outputs_set[frame_idx]
        for obj_id, binary_mask in _outputs.items():
            box_xyxy = masks_to_boxes(torch.tensor(binary_mask).unsqueeze(0)).squeeze()
            box_xyxy = normalize_bbox(box_xyxy, img_W, img_H)
            color = COLORS[obj_id % len(COLORS)]
            plot_bbox(img_H, img_W, box_xyxy, text=f"(id={obj_id})", box_format="XYXY", color=color, ax=ax)
            plot_mask(binary_mask, color=color, ax=ax)

        # points
        if points_list is not None and points_list[idx] is not None:
            show_points_with_labels(points_list[idx], points_labels_list[idx], ax=ax, marker_size=200)

    plt.tight_layout()
    plt.show()


def render_masklet_frame(img, outputs, frame_idx=None, alpha=0.5):
    """
    Overlays masklets and bounding boxes on a single image frame.
    Args:
        img: np.ndarray, shape (H, W, 3), uint8 or float32 in [0,255] or [0,1]
        outputs: dict with keys: out_boxes_xywh, out_probs, out_obj_ids, out_binary_masks
        frame_idx: int or None, for overlaying frame index text
        alpha: float, mask overlay alpha
    Returns:
        overlay: np.ndarray, shape (H, W, 3), uint8
    """
    if img.dtype == np.float32 or img.max() <= 1.0:
        img = (img * 255).astype(np.uint8)
    img = img[..., :3]  # drop alpha if present
    height, width = img.shape[:2]
    overlay = img.copy()

    for i in range(len(outputs["out_probs"])):
        obj_id = outputs["out_obj_ids"][i]
        color = COLORS[obj_id % len(COLORS)]
        color255 = (color * 255).astype(np.uint8)
        mask = outputs["out_binary_masks"][i]
        if mask.shape != img.shape[:2]:
            mask = cv2.resize(mask.astype(np.float32), (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)
        mask_bool = mask > 0.5
        for c in range(3):
            overlay[..., c][mask_bool] = (
                alpha * color255[c] + (1 - alpha) * overlay[..., c][mask_bool]
            ).astype(np.uint8)

    # Draw bounding boxes and text
    for i in range(len(outputs["out_probs"])):
        box_xywh = outputs["out_boxes_xywh"][i]
        obj_id = outputs["out_obj_ids"][i]
        prob = outputs["out_probs"][i]
        color = COLORS[obj_id % len(COLORS)]
        color255 = tuple(int(x * 255) for x in color)
        x, y, w, h = box_xywh
        x1 = int(x * width)
        y1 = int(y * height)
        x2 = int((x + w) * width)
        y2 = int((y + h) * height)
        cv2.rectangle(overlay, (x1, y1), (x2, y2), color255, 2)
        label = f"id={obj_id}, p={prob:.2f}"
        cv2.putText(
            overlay, label, (x1, max(y1 - 10, 0)),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color255, 1, cv2.LINE_AA
        )

    # Overlay frame index at the top-left corner
    if frame_idx is not None:
        cv2.putText(
            overlay, f"Frame {frame_idx}", (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2, cv2.LINE_AA
        )

    return overlay


def save_masklet_video(image_files, outputs, out_path, alpha=0.5, fps=10):
    # Each outputs dict has keys: "out_boxes_xywh", "out_probs", "out_obj_ids", "out_binary_masks"
    # image_files: list of image file paths, same length as outputs_list

    # Read first frame to get size
    first_img = plt.imread(image_files[0])
    height, width = first_img.shape[:2]
    if first_img.dtype == np.float32 or first_img.max() <= 1.0:
        first_img = (first_img * 255).astype(np.uint8)
    # Use 'mp4v' for best compatibility with VSCode playback (.mp4 files)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter('temp.mp4', fourcc, fps, (width, height))

    outputs_list = [(image_files[frame_idx], frame_idx, outputs[frame_idx]) for frame_idx in sorted(outputs.keys())]

    for img_path, frame_idx, frame_outputs in tqdm(outputs_list):
        img = plt.imread(img_path)
        overlay = render_masklet_frame(img, frame_outputs, frame_idx=frame_idx, alpha=alpha)
        writer.write(cv2.cvtColor(overlay, cv2.COLOR_RGB2BGR))

    writer.release()

    # Re-encode the video for VSCode compatibility using ffmpeg
    subprocess.run(["ffmpeg", "-y", "-i", 'temp.mp4', out_path])
    print(f"Re-encoded video saved to {out_path}")

    os.remove('temp.mp4')  # Clean up temporary file


def save_masklet_image(image_file, outputs, out_path, alpha=0.5, frame_idx=None):
    '''
    Save a single image with masklet overlays.
    '''
    img = plt.imread(image_file)
    overlay = render_masklet_frame(img, outputs, frame_idx=frame_idx, alpha=alpha)
    Image.fromarray(overlay).save(out_path)
    print(f"Overlay image saved to {out_path}")


def prepare_masks_for_visualization(frame_to_output):
    # frame_to_obj_masks --> {frame_idx: {'output_probs': np.array, `out_obj_ids`: np.array, `out_binary_masks`: np.array}}
    for frame_idx, out in frame_to_output.items():
        _processed_out = {}
        for idx, obj_id in enumerate(out["out_obj_ids"].tolist()):
            if out["out_binary_masks"][idx].any():
                _processed_out[obj_id] = out["out_binary_masks"][idx]
        frame_to_output[frame_idx] = _processed_out
    return frame_to_output
# Out:
# Converting 5000 RGB samples to LAB color space...
# Conversion to LAB complete.
# Fitting KMeans with 128 clusters on 5000 samples...
# KMeans fitting complete.

# %% [markdown]
# ## 2. Running inference

# %%
# this video has 6 objects
video_frames_dir = "/checkpoint/sam3/shared/webdemo/data/ta/static/gallery/selected_examples/0001/rgb"
prompt_text_str = "person"

# this video has ~80 objects
# video_frames_dir = "/checkpoint/sam3/shared/webdemo/data/ta/static/gallery/selected_examples/0018/rgb"
# prompt_text_str = "horse"

# %% [markdown]
# ### Opening an inference session on this video

# %%
response = model_wrapper.handle_request(
    request=dict(
        type="start_session",
        resource_path=video_frames_dir,
    )
)
session_id = response["session_id"]

# "image_files" is only needed for visualization purposes (not used by the model)
image_files = glob(os.path.join(video_frames_dir, "*.jpg"))
try:
    # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
    image_files.sort(key=lambda p: int(os.path.splitext(os.path.basename(p))[0]))
except ValueError:
    # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
    print(
        f'frame names are not in "<frame_index>.jpg" format: {image_files[:5]=}, '
        f"falling back to lexicographic sort."
    )
    image_files.sort()
# Out:
# frame loading (JPEG):   0%|          | 0/270 [00:00<?, ?it/s]INFO:sam3.model.sam3_model_web:started new session 1738f72c-8f4f-428d-8219-e29752a6876d; live sessions: ['1738f72c-8f4f-428d-8219-e29752a6876d' (270 frames)], GPU memory: 3538 MiB used and 7254 MiB reserved (max over time: 7050 MiB used and 7254 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H100 80GB HBM3', major=9, minor=0, total_memory=81109MB, multi_processor_count=132, uuid=0cbacde7-942c-0e57-def1-cbd11ab226e2, L2_cache_size=50MB)

# %%
len(image_files)
model_wrapper.model.device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ### Adding a text prompt on frame 0 and propagation throughout the video
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = model_wrapper.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)
# Out:
# INFO:sam3.model.sam3_model_web:clear all inputs across the video in session 1738f72c-8f4f-428d-8219-e29752a6876d

# %%
frame_idx = 0  # add a text prompt on frame 0
response = model_wrapper.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]
# Out:
# INFO:sam3.model.sam3_model_web:add prompt on frame 0 in session 1738f72c-8f4f-428d-8219-e29752a6876d: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO:sam3.model.sam3_demo_dense_tracking_multigpu:Running add_prompt on frame 0
# /storage/home/kalyanv/sam3/sam3/model/decoder.py:74: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# INFO:sam3.model.sam3_model_web:got 4 objects on frame 0 in session 1738f72c-8f4f-428d-8219-e29752a6876d

# %%
plt.close("all")
visualize_formatted_frame_output(
    frame_idx,
    image_files,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})],
    titles=["SAM 3 Dense Tracking outputs"],
    figsize=(6, 4),
)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family ['Liberation Sans', 'Noto Sans TC', 'Noto Sans SC', 'Noto Sans Thai', 'Noto Naskh Arabic UI', 'Noto Sans UI'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.

# %%
# we will just propagate from frame 0 to the end of the video
outputs_per_frame = {}
for response in model_wrapper.handle_stream_request(
    request=dict(
        type="propagate_in_video",
        session_id=session_id,
    )
):
    outputs_per_frame[response["frame_index"]] = response["outputs"]
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
# Out:
# INFO:sam3.model.sam3_model_web:propagate in video in session 1738f72c-8f4f-428d-8219-e29752a6876d: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# propagate_in_video:   0%|          | 0/270 [00:00<?, ?it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   1%|          | 3/270 [00:00<00:16, 16.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   2%|▏         | 5/270 [00:00<00:18, 14.11it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   3%|▎         | 7/270 [00:00<00:20, 12.87it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   3%|▎         | 9/270 [00:00<00:21, 12.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   4%|▍         | 11/270 [00:00<00:21, 11.95it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   5%|▍         | 13/270 [00:01<00:21, 11.80it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   6%|▌         | 15/270 [00:01<00:21, 11.62it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   6%|▋         | 17/270 [00:01<00:21, 11.52it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   7%|▋         | 19/270 [00:01<00:21, 11.44it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   8%|▊         | 21/270 [00:01<00:21, 11.34it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   9%|▊         | 23/270 [00:01<00:21, 11.33it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:   9%|▉         | 25/270 [00:02<00:21, 11.30it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  10%|█         | 27/270 [00:02<00:21, 11.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  11%|█         | 29/270 [00:02<00:21, 11.20it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  11%|█▏        | 31/270 [00:02<00:21, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  12%|█▏        | 33/270 [00:02<00:21, 11.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  13%|█▎        | 35/270 [00:03<00:21, 11.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  14%|█▎        | 37/270 [00:03<00:20, 11.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  14%|█▍        | 39/270 [00:03<00:20, 11.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  15%|█▌        | 41/270 [00:03<00:20, 11.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  16%|█▌        | 43/270 [00:03<00:20, 11.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  17%|█▋        | 45/270 [00:03<00:20, 11.15it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  17%|█▋        | 47/270 [00:04<00:19, 11.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  18%|█▊        | 49/270 [00:04<00:19, 11.18it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  19%|█▉        | 51/270 [00:04<00:19, 11.20it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  20%|█▉        | 53/270 [00:04<00:19, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  20%|██        | 55/270 [00:04<00:19, 11.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  21%|██        | 57/270 [00:04<00:18, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  22%|██▏       | 59/270 [00:05<00:18, 11.29it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  23%|██▎       | 61/270 [00:05<00:18, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  23%|██▎       | 63/270 [00:05<00:18, 11.30it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  24%|██▍       | 65/270 [00:05<00:18, 11.31it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  25%|██▍       | 67/270 [00:05<00:18, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  26%|██▌       | 69/270 [00:06<00:17, 11.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  26%|██▋       | 71/270 [00:06<00:17, 11.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  27%|██▋       | 73/270 [00:06<00:17, 11.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  28%|██▊       | 75/270 [00:06<00:17, 11.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  29%|██▊       | 77/270 [00:06<00:17, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  29%|██▉       | 79/270 [00:06<00:17, 11.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  30%|███       | 81/270 [00:07<00:16, 11.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  31%|███       | 83/270 [00:07<00:16, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  31%|███▏      | 85/270 [00:07<00:16, 11.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  32%|███▏      | 87/270 [00:07<00:16, 11.24it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  33%|███▎      | 89/270 [00:07<00:16, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  34%|███▎      | 91/270 [00:07<00:15, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  34%|███▍      | 93/270 [00:08<00:15, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  35%|███▌      | 95/270 [00:08<00:15, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  36%|███▌      | 97/270 [00:08<00:15, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  37%|███▋      | 99/270 [00:08<00:15, 11.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  37%|███▋      | 101/270 [00:08<00:14, 11.32it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  38%|███▊      | 103/270 [00:09<00:14, 11.31it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  39%|███▉      | 105/270 [00:09<00:14, 11.28it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  40%|███▉      | 107/270 [00:09<00:14, 11.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  40%|████      | 109/270 [00:09<00:14, 11.24it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  41%|████      | 111/270 [00:09<00:14, 11.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  42%|████▏     | 113/270 [00:09<00:14, 11.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  43%|████▎     | 115/270 [00:10<00:24,  6.35it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  43%|████▎     | 117/270 [00:10<00:21,  7.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  44%|████▍     | 119/270 [00:10<00:18,  8.09it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  45%|████▍     | 121/270 [00:11<00:16,  8.81it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  46%|████▌     | 123/270 [00:11<00:15,  9.42it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  46%|████▋     | 125/270 [00:11<00:14,  9.93it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  47%|████▋     | 127/270 [00:11<00:13, 10.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  48%|████▊     | 129/270 [00:11<00:13, 10.54it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  49%|████▊     | 131/270 [00:12<00:12, 10.76it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  49%|████▉     | 133/270 [00:12<00:12, 10.90it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  50%|█████     | 135/270 [00:12<00:12, 10.97it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  51%|█████     | 137/270 [00:12<00:12, 11.03it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  51%|█████▏    | 139/270 [00:12<00:11, 11.00it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  52%|█████▏    | 141/270 [00:12<00:11, 11.08it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  53%|█████▎    | 143/270 [00:13<00:11, 11.14it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  54%|█████▎    | 145/270 [00:13<00:11, 11.09it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  54%|█████▍    | 147/270 [00:13<00:11, 11.11it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  55%|█████▌    | 149/270 [00:13<00:10, 11.18it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  56%|█████▌    | 151/270 [00:13<00:10, 11.20it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  57%|█████▋    | 153/270 [00:13<00:10, 11.24it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  57%|█████▋    | 155/270 [00:14<00:10, 11.25it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  58%|█████▊    | 157/270 [00:14<00:10, 11.25it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  59%|█████▉    | 159/270 [00:14<00:09, 11.25it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  60%|█████▉    | 161/270 [00:14<00:09, 11.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  60%|██████    | 163/270 [00:14<00:09, 11.25it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  61%|██████    | 165/270 [00:15<00:09, 11.25it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  62%|██████▏   | 167/270 [00:15<00:09, 11.26it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  63%|██████▎   | 169/270 [00:15<00:09, 11.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  63%|██████▎   | 171/270 [00:15<00:08, 11.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  64%|██████▍   | 173/270 [00:15<00:09, 10.55it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  65%|██████▍   | 175/270 [00:15<00:09, 10.44it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  66%|██████▌   | 177/270 [00:16<00:08, 10.37it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  66%|██████▋   | 179/270 [00:16<00:08, 10.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# INFO:sam3.model.sam3_dense_shared_multigpu:Removing object 4 at frame 179 since it overlaps with another track 0 at frames: [172, 173, 174, 175, 176, 177, 178, 179]
# WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# ...
# propagate_in_video:  80%|████████  | 217/270 [00:20<00:05,  9.34it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  81%|████████  | 218/270 [00:20<00:05,  9.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  81%|████████  | 219/270 [00:20<00:05,  9.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  81%|████████▏ | 220/270 [00:20<00:05,  9.24it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  82%|████████▏ | 221/270 [00:20<00:05,  9.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  82%|████████▏ | 222/270 [00:20<00:05,  9.28it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  83%|████████▎ | 223/270 [00:20<00:05,  9.27it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  83%|████████▎ | 224/270 [00:20<00:04,  9.24it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  83%|████████▎ | 225/270 [00:21<00:04,  9.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  84%|████████▎ | 226/270 [00:21<00:04,  9.20it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  84%|████████▍ | 227/270 [00:21<00:04,  9.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  84%|████████▍ | 228/270 [00:21<00:04,  9.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  85%|████████▍ | 229/270 [00:21<00:04,  9.18it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  85%|████████▌ | 230/270 [00:21<00:04,  9.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  86%|████████▌ | 231/270 [00:21<00:04,  9.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  86%|████████▌ | 232/270 [00:21<00:04,  9.13it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  86%|████████▋ | 233/270 [00:21<00:04,  9.15it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  87%|████████▋ | 234/270 [00:22<00:03,  9.13it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  87%|████████▋ | 235/270 [00:22<00:03,  9.12it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  87%|████████▋ | 236/270 [00:22<00:03,  9.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  88%|████████▊ | 237/270 [00:22<00:03,  9.14it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  88%|████████▊ | 238/270 [00:22<00:03,  9.12it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  89%|████████▊ | 239/270 [00:22<00:03,  9.11it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  89%|████████▉ | 240/270 [00:22<00:03,  9.09it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  89%|████████▉ | 241/270 [00:22<00:03,  9.09it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  90%|████████▉ | 242/270 [00:22<00:03,  9.12it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  90%|█████████ | 243/270 [00:23<00:02,  9.15it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  90%|█████████ | 244/270 [00:23<00:02,  9.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  91%|█████████ | 245/270 [00:23<00:02,  9.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  91%|█████████ | 246/270 [00:23<00:02,  9.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  91%|█████████▏| 247/270 [00:23<00:02,  9.18it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  92%|█████████▏| 248/270 [00:23<00:02,  9.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  92%|█████████▏| 249/270 [00:23<00:02,  9.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  93%|█████████▎| 250/270 [00:23<00:02,  9.15it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  93%|█████████▎| 251/270 [00:23<00:02,  9.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  93%|█████████▎| 252/270 [00:24<00:01,  9.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  94%|█████████▎| 253/270 [00:24<00:01,  9.18it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  94%|█████████▍| 254/270 [00:24<00:01,  9.24it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  94%|█████████▍| 255/270 [00:24<00:01,  9.21it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  95%|█████████▍| 256/270 [00:24<00:01,  9.22it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  95%|█████████▌| 257/270 [00:24<00:01,  9.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  96%|█████████▌| 258/270 [00:24<00:01,  9.17it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  96%|█████████▌| 259/270 [00:24<00:01,  9.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  96%|█████████▋| 260/270 [00:24<00:01,  9.18it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  97%|█████████▋| 261/270 [00:25<00:00,  9.16it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  97%|█████████▋| 262/270 [00:25<00:00,  9.15it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  97%|█████████▋| 263/270 [00:25<00:00,  9.15it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  98%|█████████▊| 264/270 [00:25<00:00,  9.14it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  98%|█████████▊| 265/270 [00:25<00:00,  9.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  99%|█████████▊| 266/270 [00:25<00:00,  9.23it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  99%|█████████▉| 267/270 [00:25<00:00,  9.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video:  99%|█████████▉| 268/270 [00:25<00:00,  9.19it/s]WARNING:root:Falling back to CPU mask NMS implementation -- please install `torch_generic_nms` via
# 	pip uninstall -y torch_generic_nms; TORCH_CUDA_ARCH_LIST="8.0 9.0" pip install git+https://github.com/ronghanghu/torch_generic_nms
# propagate_in_video: 100%|██████████| 270/270 [00:25<00:00, 10.39it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# INFO:sam3.model.sam3_model_web:propagation ended in session 1738f72c-8f4f-428d-8219-e29752a6876d; live sessions: ['1738f72c-8f4f-428d-8219-e29752a6876d' (270 frames)], GPU memory: 7381 MiB used and 8652 MiB reserved (max over time: 8418 MiB used and 8652 MiB reserved)

# %%
vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    print(f"frame {frame_idx}")
    visualize_formatted_frame_output(
        frame_idx,
        image_files,
        outputs_list=[outputs_per_frame],
        titles=["SAM 3 Dense Tracking outputs"],
        figsize=(6, 4),
    )
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# frame 180
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# frame 240
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Liberation Sans' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans TC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans SC' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans Thai' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Naskh Arabic UI' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Noto Sans UI' not found.
