# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %%
import copy
import json
import os

import numpy as np

from pycocotools.coco import COCO
from sam3.train.eval.demo_eval import DemoEvaluator

# %%
# Update to the directory where the GT annotation and PRED files exist
GT_DIR = "/checkpoint/sam3/haithamkhedr/shared/sam3_image_results/gt-annotations"  # PUT YOUR PATH HERE
PRED_DIR = "/checkpoint/sam3/haithamkhedr/workspace/occhi/results/" # PUT YOUR PATH HERE
PRED_DIR = "/checkpoint/vision_encoder/haithamkhedr/shared/experiments/eval_saco_gold/plm_1b_grounding_sft_sam3_full_93m_multiturn_448_vanilla_80neg_nocrowed/2025_10_30_plm_grounding/"

# %%
# Relative file names for GT and prediction files for 7 SA-Co/Gold subsets
saco_gold_gt_and_pred_files = {
    # MetaCLIP Captioner
    "metaclip": {
        "gt_fname": [
            "gold_metaclip_merged_a_release_test.json",
            "gold_metaclip_merged_b_release_test.json",
            "gold_metaclip_merged_c_release_test.json",
        ],
        "pred_fname": "raw_results_sam3_gold_metaclip_detection-plm_grounding.json",
    },
    # SA-1B captioner
    "sa1b": {
        "gt_fname": [
            "gold_sa1b_merged_a_release_test.json",
            "gold_sa1b_merged_b_release_test.json",
            "gold_sa1b_merged_c_release_test.json",
        ],
        "pred_fname": "raw_results_sam3_gold_sa1b_detection-plm_grounding.json",
    },
    # Crowded
    "crowded": {
        "gt_fname": [
            "gold_crowded_merged_a_release_test.json",
            "gold_crowded_merged_b_release_test.json",
            "gold_crowded_merged_c_release_test.json",
        ],
        "pred_fname": "raw_results_sam3_gold_crowded_detection-plm_grounding.json",
    },
    # FG Food
    "fg_food": {
        "gt_fname": [
            "gold_fg_food_merged_a_release_test.json",
            "gold_fg_food_merged_b_release_test.json",
            "gold_fg_food_merged_c_release_test.json",
        ],
        "pred_fname": "raw_results_sam3_gold_fg_food_detection-plm_grounding.json",
    },
    # FG Sports
    "fg_sports_equipment": {
        "gt_fname": [
            "gold_fg_sports_equipment_merged_a_release_test.json",
            "gold_fg_sports_equipment_merged_b_release_test.json",
            "gold_fg_sports_equipment_merged_c_release_test.json",
        ],
        "pred_fname": "raw_results_sam3_gold_fg_sports_detection-plm_grounding.json",
    },
    # Attributes
    "attributes": {
        "gt_fname": [
            "gold_attributes_merged_a_release_test.json",
            "gold_attributes_merged_b_release_test.json",
            "gold_attributes_merged_c_release_test.json",
        ],
        # "pred_fname": "raw_result_file.json",
        "pred_fname": "raw_results_sam3_gold_attributes_detection-plm_grounding.json"
    },
    # Wiki common
    "wiki_common": {
        "gt_fname": [
            "gold_wiki_common_merged_a_release_test.json",
            "gold_wiki_common_merged_b_release_test.json",
            "gold_wiki_common_merged_c_release_test.json",
        ],
        "pred_fname": "raw_results_sam3_gold_wiki_detection-plm_grounding.json",
    },
}

# %%
import torch
import ast
def extract_all_bounding_boxes(text):
    import re
    """Extracts any list of arbitrary length from a string."""
    pattern = r"\[\s*([^\[\]]*?)\s*\]"
    extracted_lists = [
        [float(num.strip()) for num in match.split(",")] for match in re.findall(pattern, text)
    ]
    return extracted_lists
    
class PostProcessorMerged:
    def __init__(self, predictions_path, img_ids):
        with open(predictions_path, "r") as f:
            self.data_anns = json.load(f)
        self.img_ids = img_ids

    def process_results(self):
        d = {
            "scores": np.array([]),
            "labels": np.array([], dtype=int),
            "boxes": [],
            # "masks_rle": [],
        }
        imgToAnns = {img_id: copy.deepcopy(d) for img_id in self.img_ids}
        for ann in self.data_anns:
            if ann["img_id"] not in self.img_ids:
                continue
            num_preds = len(ann["prediction"])
            imgToAnns[ann["img_id"]]["scores"] = np.append(
                imgToAnns[ann["img_id"]]["scores"], [ann.get("score", 1.0)] * num_preds
            )
            imgToAnns[ann["img_id"]]["labels"] = np.append(
                imgToAnns[ann["img_id"]]["labels"], [1] * num_preds
            )
            if ann["prediction"] == "N/A.":
                boxes = torch.zeros(0,4)
            else:
                try:
                    # boxes = ast.literal_eval(ann["prediction"].removesuffix('.'))
                    boxes = extract_all_bounding_boxes(ann["prediction"])
                except Exception as e:
                    print(ann["prediction"])
                    raise e
                    
            imgToAnns[ann["img_id"]]["boxes"] += boxes
            imgToAnns[ann["img_id"]]["boxes"] = torch.tensor(imgToAnns[ann["img_id"]]["boxes"]).view(-1,4)
            imgToAnns[ann["img_id"]]["boxes"][:,0] /= ann["img_w"]
            imgToAnns[ann["img_id"]]["boxes"][:,2] /= ann["img_w"]
            imgToAnns[ann["img_id"]]["boxes"][:,1] /= ann["img_h"]
            imgToAnns[ann["img_id"]]["boxes"][:,3] /= ann["img_h"]
        return imgToAnns

# %% [markdown]
# <b>Run offline evaluation for all 7 SA-Co/Gold subsets</b>

# %%
results = ""

for subset_name, values in saco_gold_gt_and_pred_files.items():
    print("Processing subset: ", subset_name)
    gt_fnames = values["gt_fname"]
    pred_fname = values["pred_fname"]
    gt_fname_full_paths = [
        os.path.join(GT_DIR, gt_fname) for gt_fname in gt_fnames
    ]
    pred_fname_full_path = os.path.join(PRED_DIR, pred_fname)
    coco = COCO(gt_fname_full_paths[0])

    img_ids = list(
        sorted(
            [
                img["id"]
                for img in coco.dataset["images"]
                if img["is_instance_exhaustive"]
            ]
        )
    )
    iou_type = "bbox"
    evaluator = DemoEvaluator(
        coco_gt=gt_fname_full_paths,
        iou_types=[iou_type],
        threshold=0.5,
        dump_dir=None,
        postprocessor=PostProcessorMerged(
            predictions_path=pred_fname_full_path, img_ids=img_ids
        ),
        average_by_rarity=False,
        gather_pred_via_filesys=False,
        exhaustive_only=True,
    )
    evaluator.update()
    summary = evaluator.compute_synced()
    
    cgf1 = str(round(summary[f"coco_eval_{iou_type}_oracle_CGF1"] * 100, 2))
    cgf1m = str(round(summary[f"coco_eval_{iou_type}_oracle_CGF1_micro"] * 100, 2))
    il_mcc = str(round(summary[f"coco_eval_{iou_type}_oracle_IL_MCC"], 2))
    pmf1 = str(round(summary[f"coco_eval_{iou_type}_oracle_Macro_F1"] * 100, 2))
    pmf1m = str(round(summary[f"coco_eval_{iou_type}_oracle_positive_micro_F1"] * 100, 2))
    demof1 = str(round(summary[f"coco_eval_{iou_type}_oracle_F1"] * 100, 2))
    precision = str(round(summary[f"coco_eval_{iou_type}_oracle_Precision"] * 100, 2))
    recall = str(round(summary[f"coco_eval_{iou_type}_oracle_Recall"] * 100, 2))
    final_str = f"{cgf1},{cgf1m},{il_mcc},{pmf1},{pmf1m},{precision},{recall},{demof1}"
    results += subset_name + ": " + final_str + "\n"
# Out:
# Processing subset:  metaclip
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.16s)
# creating index...
# index created!
# WARNING: 152 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.539
#  Average precision  @[ IoU=0.50:0.95] = 0.519
#  Average recall     @[ IoU=0.50:0.95] = 0.365
#  Average F1         @[ IoU=0.50:0.95] = 0.429
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.717
#  Average IL_precision                = 0.838
#  Average IL_recall                   = 0.744
#  Average IL_F1                       = 0.788
#  Average IL_FPR                      = 0.028
#  Average IL_MCC                      = 0.751
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.408
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.972
#  Average CGF1       @[ IoU=0.50     ] = 0.613
#  Average precision  @[ IoU=0.50     ] = 0.624
#  Average recall     @[ IoU=0.50     ] = 0.439
#  Average F1         @[ IoU=0.50     ] = 0.515
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.816
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.458
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.972
#  Average CGF1       @[ IoU=0.75     ] = 0.557
#  Average precision  @[ IoU=0.75     ] = 0.544
#  Average recall     @[ IoU=0.75     ] = 0.383
#  Average F1         @[ IoU=0.75     ] = 0.449
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.741
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.419
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.972
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.347
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.628
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.462
#  Average CGF1_micro @[ IoU=0.50     ] = 0.417
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.754
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.555
#  Average CGF1_micro @[ IoU=0.75     ] = 0.364
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.658
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.484
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.401
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.534
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.456
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.607
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.414
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.552
# Processing subset:  sa1b
# loading annotations into memory...
# Done (t=0.26s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.23s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.23s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.24s)
# creating index...
# index created!
# WARNING: 170 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.489
#  Average precision  @[ IoU=0.50:0.95] = 0.527
#  Average recall     @[ IoU=0.50:0.95] = 0.311
#  Average F1         @[ IoU=0.50:0.95] = 0.391
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.675
#  Average IL_precision                = 0.969
#  Average IL_recall                   = 0.748
#  Average IL_F1                       = 0.844
#  Average IL_FPR                      = 0.029
#  Average IL_MCC                      = 0.725
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.380
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.971
#  Average CGF1       @[ IoU=0.50     ] = 0.575
#  Average precision  @[ IoU=0.50     ] = 0.676
#  Average recall     @[ IoU=0.50     ] = 0.399
#  Average F1         @[ IoU=0.50     ] = 0.502
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.793
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.437
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.971
#  Average CGF1       @[ IoU=0.75     ] = 0.503
#  Average precision  @[ IoU=0.75     ] = 0.545
#  Average recall     @[ IoU=0.75     ] = 0.322
#  Average F1         @[ IoU=0.75     ] = 0.404
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.694
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.389
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.971
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.286
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.541
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.395
#  Average CGF1_micro @[ IoU=0.50     ] = 0.367
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.694
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.507
#  Average CGF1_micro @[ IoU=0.75     ] = 0.296
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.560
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.409
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.366
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.505
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.430
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.593
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.376
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.519
# Processing subset:  crowded
# loading annotations into memory...
# Done (t=0.27s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.24s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.25s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.26s)
# creating index...
# index created!
# WARNING: 217 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.408
#  Average precision  @[ IoU=0.50:0.95] = 0.395
#  Average recall     @[ IoU=0.50:0.95] = 0.250
#  Average F1         @[ IoU=0.50:0.95] = 0.306
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.529
#  Average IL_precision                = 0.876
#  Average IL_recall                   = 0.765
#  Average IL_F1                       = 0.817
#  Average IL_FPR                      = 0.031
#  Average IL_MCC                      = 0.772
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.189
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.969
#  Average CGF1       @[ IoU=0.50     ] = 0.504
#  Average precision  @[ IoU=0.50     ] = 0.522
#  Average recall     @[ IoU=0.50     ] = 0.330
#  Average F1         @[ IoU=0.50     ] = 0.405
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.653
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.223
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.969
#  Average CGF1       @[ IoU=0.75     ] = 0.428
#  Average precision  @[ IoU=0.75     ] = 0.422
#  Average recall     @[ IoU=0.75     ] = 0.267
#  Average F1         @[ IoU=0.75     ] = 0.327
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.555
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.197
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.969
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.244
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.430
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.316
#  Average CGF1_micro @[ IoU=0.50     ] = 0.322
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.568
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.418
#  Average CGF1_micro @[ IoU=0.75     ] = 0.261
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.459
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.338
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.312
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.405
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.386
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.500
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.328
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.425
# Processing subset:  fg_food
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# WARNING: 80 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.558
#  Average precision  @[ IoU=0.50:0.95] = 0.588
#  Average recall     @[ IoU=0.50:0.95] = 0.293
#  Average F1         @[ IoU=0.50:0.95] = 0.391
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.725
#  Average IL_precision                = 0.811
#  Average IL_recall                   = 0.769
#  Average IL_F1                       = 0.789
#  Average IL_FPR                      = 0.018
#  Average IL_MCC                      = 0.769
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.415
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.982
#  Average CGF1       @[ IoU=0.50     ] = 0.610
#  Average precision  @[ IoU=0.50     ] = 0.661
#  Average recall     @[ IoU=0.50     ] = 0.330
#  Average F1         @[ IoU=0.50     ] = 0.440
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.792
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.449
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.982
#  Average CGF1       @[ IoU=0.75     ] = 0.569
#  Average precision  @[ IoU=0.75     ] = 0.614
#  Average recall     @[ IoU=0.75     ] = 0.306
#  Average F1         @[ IoU=0.75     ] = 0.408
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.740
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.426
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.982
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.323
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.735
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.419
#  Average CGF1_micro @[ IoU=0.50     ] = 0.363
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.827
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.471
#  Average CGF1_micro @[ IoU=0.75     ] = 0.337
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.768
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.438
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.429
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.557
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.469
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.609
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.438
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.569
# Processing subset:  fg_sports_equipment
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# WARNING: 30 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.645
#  Average precision  @[ IoU=0.50:0.95] = 0.583
#  Average recall     @[ IoU=0.50:0.95] = 0.525
#  Average F1         @[ IoU=0.50:0.95] = 0.552
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.809
#  Average IL_precision                = 0.854
#  Average IL_recall                   = 0.805
#  Average IL_F1                       = 0.829
#  Average IL_FPR                      = 0.026
#  Average IL_MCC                      = 0.798
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.555
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.974
#  Average CGF1       @[ IoU=0.50     ] = 0.707
#  Average precision  @[ IoU=0.50     ] = 0.663
#  Average recall     @[ IoU=0.50     ] = 0.597
#  Average F1         @[ IoU=0.50     ] = 0.628
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.887
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.601
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.974
#  Average CGF1       @[ IoU=0.75     ] = 0.661
#  Average precision  @[ IoU=0.75     ] = 0.604
#  Average recall     @[ IoU=0.75     ] = 0.544
#  Average F1         @[ IoU=0.75     ] = 0.573
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.829
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.570
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.974
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.466
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.659
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.584
#  Average CGF1_micro @[ IoU=0.50     ] = 0.530
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.749
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.665
#  Average CGF1_micro @[ IoU=0.75     ] = 0.483
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.683
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.606
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.520
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.652
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.570
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.714
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.533
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.668
# Processing subset:  attributes
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# WARNING: 10 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.702
#  Average precision  @[ IoU=0.50:0.95] = 0.715
#  Average recall     @[ IoU=0.50:0.95] = 0.585
#  Average F1         @[ IoU=0.50:0.95] = 0.643
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.889
#  Average IL_precision                = 0.836
#  Average IL_recall                   = 0.819
#  Average IL_F1                       = 0.827
#  Average IL_FPR                      = 0.036
#  Average IL_MCC                      = 0.789
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.676
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.964
#  Average CGF1       @[ IoU=0.50     ] = 0.735
#  Average precision  @[ IoU=0.50     ] = 0.763
#  Average recall     @[ IoU=0.50     ] = 0.625
#  Average F1         @[ IoU=0.50     ] = 0.687
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.931
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.706
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.964
#  Average CGF1       @[ IoU=0.75     ] = 0.709
#  Average precision  @[ IoU=0.75     ] = 0.727
#  Average recall     @[ IoU=0.75     ] = 0.595
#  Average F1         @[ IoU=0.75     ] = 0.655
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.898
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.683
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.964
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.544
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.837
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.689
#  Average CGF1_micro @[ IoU=0.50     ] = 0.580
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.894
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.735
#  Average CGF1_micro @[ IoU=0.75     ] = 0.553
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.852
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.701
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.575
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.728
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.602
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.763
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.580
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.735
# Processing subset:  wiki_common
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.11s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.13s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.14s)
# creating index...
# index created!
# WARNING: 21 images were not predicted!
# Demo metric, IoU type=bbox
#  Average CGF1       @[ IoU=0.50:0.95] = 0.475
#  Average precision  @[ IoU=0.50:0.95] = 0.472
#  Average recall     @[ IoU=0.50:0.95] = 0.285
#  Average F1         @[ IoU=0.50:0.95] = 0.355
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.795
#  Average IL_precision                = 0.662
#  Average IL_recall                   = 0.557
#  Average IL_F1                       = 0.605
#  Average IL_FPR                      = 0.008
#  Average IL_MCC                      = 0.597
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.376
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.992
#  Average CGF1       @[ IoU=0.50     ] = 0.514
#  Average precision  @[ IoU=0.50     ] = 0.532
#  Average recall     @[ IoU=0.50     ] = 0.321
#  Average F1         @[ IoU=0.50     ] = 0.400
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.862
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.407
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.992
#  Average CGF1       @[ IoU=0.75     ] = 0.476
#  Average precision  @[ IoU=0.75     ] = 0.483
#  Average recall     @[ IoU=0.75     ] = 0.291
#  Average F1         @[ IoU=0.75     ] = 0.363
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.799
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.376
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.992
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.237
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.660
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.398
#  Average CGF1_micro @[ IoU=0.50     ] = 0.267
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.743
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.448
#  Average CGF1_micro @[ IoU=0.75     ] = 0.243
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.675
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.407
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.264
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.443
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.287
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.480
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.265
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.445

# %%
print("Subset name, CG_F1, CG_F1_m, IL_MCC, pmF1, pmF1_m, Precision, Recall, demoF1")
print(results)
# Out:
# Subset name, CG_F1, CG_F1_m, IL_MCC, pmF1, pmF1_m, Precision, Recall, demoF1
# metaclip: 53.79,32.81,0.75,71.68,43.72,44.2,36.48,39.96
# sa1b: 48.95,27.09,0.73,67.46,37.33,45.3,31.1,36.88
# crowded: 40.59,21.84,0.77,52.68,28.34,30.24,25.01,27.37
# fg_food: 55.36,30.31,0.77,72.18,39.51,50.07,28.78,36.54
# fg_sports_equipment: 64.55,42.07,0.8,81.01,52.79,47.97,52.58,50.16
# attributes: 70.17,53.32,0.79,88.82,67.5,68.28,58.74,63.15
# wiki_common: 46.97,21.2,0.59,79.16,35.74,35.5,28.36,31.52

# %%
print("Subset name, CG_F1, CG_F1_m, IL_MCC, pmF1, pmF1_m, demoF1")
print(results)
# Out:
# Subset name, CG_F1, CG_F1_m, IL_MCC, pmF1, pmF1_m, demoF1
# metaclip: 53.86,34.69,0.75,71.69,46.17,51.92,36.51,42.87
# sa1b: 48.92,28.63,0.72,67.48,39.5,52.66,31.11,39.11
# crowded: 40.81,24.39,0.77,52.9,31.62,39.52,25.01,30.62
# fg_food: 55.76,32.25,0.77,72.49,41.93,58.78,29.33,39.13
# fg_sports_equipment: 64.55,46.62,0.8,80.92,58.45,58.27,52.51,55.24
# attributes: 70.19,54.37,0.79,88.92,68.89,71.47,58.52,64.35
# wiki_common: 47.45,23.72,0.6,79.54,39.76,47.23,28.47,35.52

# %%
import matplotlib.pyplot as plt
def show_box(boxes, ax, mode="xyxy", color='g'):

    for box in boxes:
        if mode == "xywh":
            x0, y0 = box[0], box[1]
            w, h = box[2], box[3]
        else:
            x0, y0 = box[0], box[1]
            w, h = box[2] - box[0], box[3] - box[1]
        ax.add_patch(plt.Rectangle((x0, y0), w, h, edgecolor=color, facecolor=(0, 0, 0, 0), lw=2))

# %%
gt_anns = coco.loadAnns(coco.getAnnIds(pred_id))
gt_bboxes = torch.tensor([ann["bbox"] for ann in gt_anns]).view(-1,4)

# %%
pred_fname_full_path = "/checkpoint/sam3/haithamkhedr/workspace/occhi/raw_result_file.json"
gt_fname_full_paths = "/checkpoint/sam3/haithamkhedr/workspace/occhi/sam3_gold/gold_attributes_merged_a_test.json"
coco = COCO(gt_fname_full_paths)
img_ids = list(
        sorted(
            [
                img["id"]
                for img in coco.dataset["images"]
                if img["is_instance_exhaustive"]
            ]
        )
    )
num_vis = 20
predictions_path=pred_fname_full_path
img_ids=img_ids
postprocessor = PostProcessorMerged(
    predictions_path=predictions_path, img_ids=img_ids
)
predictions = postprocessor.process_results()
preds_ids = list(predictions.keys())
img_id_to_preds = {id: [ann for ann in postprocessor.data_anns if ann["img_id"] == id] for id in img_ids}
img_id_to_img_path = {k: v[0]["image_path"] for k,v in img_id_to_preds.items()}
img_id_to_wh = {k: (v[0]["img_w"], v[0]["img_h"]) for k,v in img_id_to_preds.items()}
img_id_to_prompt= {k: v[0]["prompt"].split(':')[-1].strip() for k,v in img_id_to_preds.items()}
fname_2_preds = {v[0]['image_path']: img_id_to_preds[k] for k,v in img_id_to_preds.items()}
start = 7000
for img_idx in range(start, start+num_vis):
    pred_id = preds_ids[img_idx]
    image_path = img_id_to_img_path[pred_id]

    text = ["labels"]
    wh = img_id_to_wh[pred_id]
    preds = predictions[pred_id]
    boxes =preds["boxes"]
    boxes[:,0] *= wh[0]
    boxes[:,2] *= wh[0]
    boxes[:,1] *= wh[1]
    boxes[:,3] *= wh[1]
    gt_anns = coco.loadAnns(coco.getAnnIds(pred_id))
    gt_bboxes = torch.tensor([ann["bbox"] for ann in gt_anns]).view(-1,4)
    gt_bboxes[:,0] *= wh[0]
    gt_bboxes[:,2] *= wh[0]
    gt_bboxes[:,1] *= wh[1]
    gt_bboxes[:,3] *= wh[1]
    if len(text) == 0:
        continue
    plt.figure(figsize=(12,8))
    plt.imshow(plt.imread(image_path))
    ax = plt.gca()
    show_box(boxes, ax, mode="xyxy")
    # coco.showAnns(gt_anns, draw_bbox=False)
    show_box(gt_bboxes, ax, color='r', mode="xywh")
    plt.title(f"{img_id_to_prompt[pred_id]}")
    plt.axis("off")
    plt.show()

# %%
for img_id, preds in predictions.items():
        if img_id != pred_id:
            continue
        else:
            print(img_id, pred_id)

# %%
fname_2_preds["/checkpoint/sam3/shared/data/metaclip_merged/1/100001/metaclip_1_100001_002fb0d001d06012870368b2.jpeg"]

# %%
img_id_to_ann[pred_id]

# %%
for k, img2ann in img_id_to_ann.items():
    if len(img2ann) > 1:
        print(k, img2ann)
        break
