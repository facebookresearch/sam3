# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.

# %%
import copy
import json
import os

import numpy as np

from pycocotools.coco import COCO
from sam3.train.eval.demo_eval import DemoEvaluator

# %%
# Update to the directory where the GT annotation and PRED files exist
GT_DIR = "/fsx-onevision/shoubhikdn/release/roboflow/gt-annotations/"  # PUT YOUR PATH HERE
PRED_DIR = "/fsx-onevision/shoubhikdn/release/sam3_predictions/arxiv/" # PUT YOUR PATH HERE

# %%
# Relative file names for GT and prediction files for 7 SA-Co/Gold subsets
saco_gold_gt_and_pred_files = {
    # MetaCLIP Captioner
    "metaclip": {
        "gt_fname": [
            "gold_metaclip_merged_a_release_test.json",
            "gold_metaclip_merged_b_release_test.json",
            "gold_metaclip_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_metaclip_captioner.json",
    },
    # SA-1B captioner
    "sa1b": {
        "gt_fname": [
            "gold_sa1b_merged_a_release_test.json",
            "gold_sa1b_merged_b_release_test.json",
            "gold_sa1b_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_sa1b_captioner.json",
    },
    # Crowded
    "crowded": {
        "gt_fname": [
            "gold_crowded_merged_a_release_test.json",
            "gold_crowded_merged_b_release_test.json",
            "gold_crowded_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_crowded.json",
    },
    # FG Food
    "fg_food": {
        "gt_fname": [
            "gold_fg_food_merged_a_release_test.json",
            "gold_fg_food_merged_b_release_test.json",
            "gold_fg_food_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_fg_food.json",
    },
    # FG Sports
    "fg_sports_equipment": {
        "gt_fname": [
            "gold_fg_sports_equipment_merged_a_release_test.json",
            "gold_fg_sports_equipment_merged_b_release_test.json",
            "gold_fg_sports_equipment_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_fg_sports_equipment.json",
    },
    # Attributes
    "attributes": {
        "gt_fname": [
            "gold_attributes_merged_a_release_test.json",
            "gold_attributes_merged_b_release_test.json",
            "gold_attributes_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_attr.json",
    },
    # Wiki common
    "wiki_common": {
        "gt_fname": [
            "gold_wiki_common_merged_a_release_test.json",
            "gold_wiki_common_merged_b_release_test.json",
            "gold_wiki_common_merged_c_release_test.json",
        ],
        "pred_fname": "coco_predictions_gold_wiki_common.json",
    },
}

# %%
class PostProcessorMerged:
    def __init__(self, predictions_path, img_ids):
        with open(predictions_path, "r") as f:
            self.data_anns = json.load(f)
        self.img_ids = img_ids

    def process_results(self):
        d = {
            "scores": np.array([]),
            "labels": np.array([], dtype=int),
            "masks_rle": [],
        }
        imgToAnns = {img_id: copy.deepcopy(d) for img_id in self.img_ids}
        for ann in self.data_anns:
            if ann["image_id"] not in self.img_ids:
                continue
            imgToAnns[ann["image_id"]]["scores"] = np.append(
                imgToAnns[ann["image_id"]]["scores"], ann["score"]
            )
            imgToAnns[ann["image_id"]]["labels"] = np.append(
                imgToAnns[ann["image_id"]]["labels"], ann["category_id"]
            )
            imgToAnns[ann["image_id"]]["masks_rle"].append(ann["segmentation"])

        return imgToAnns

# %% [markdown]
# <b>Run offline evaluation for all 7 SA-Co/Gold subsets</b>

# %%
results = ""

for subset_name, values in saco_gold_gt_and_pred_files.items():
    print("Processing subset: ", subset_name)
    gt_fnames = values["gt_fname"]
    pred_fname = values["pred_fname"]
    gt_fname_full_paths = [
        os.path.join(GT_DIR, gt_fname) for gt_fname in gt_fnames
    ]
    pred_fname_full_path = os.path.join(PRED_DIR, pred_fname)
    coco = COCO(gt_fname_full_paths[0])

    img_ids = list(
        sorted(
            [
                img["id"]
                for img in coco.dataset["images"]
                if img["is_instance_exhaustive"]
            ]
        )
    )

    evaluator = DemoEvaluator(
        coco_gt=gt_fname_full_paths,
        iou_types=["segm"],
        threshold=0.5,
        dump_dir=None,
        postprocessor=PostProcessorMerged(
            predictions_path=pred_fname_full_path, img_ids=img_ids
        ),
        average_by_rarity=False,
        gather_pred_via_filesys=False,
        exhaustive_only=True,
    )
    evaluator.update()
    summary = evaluator.compute_synced()

    cgf1 = str(round(summary["coco_eval_masks_oracle_CGF1"] * 100, 2))
    cgf1m = str(round(summary["coco_eval_masks_oracle_CGF1_micro"] * 100, 2))
    il_mcc = str(round(summary["coco_eval_masks_oracle_IL_MCC"], 2))
    pmf1 = str(round(summary["coco_eval_masks_oracle_Macro_F1"] * 100, 2))
    pmf1m = str(round(summary["coco_eval_masks_oracle_positive_micro_F1"] * 100, 2))
    demof1 = str(round(summary["coco_eval_masks_oracle_F1"] * 100, 2))
    final_str = f"{cgf1},{cgf1m},{il_mcc},{pmf1},{pmf1m},{demof1}"
    results += subset_name + ": " + final_str + "\n"
# Out:
# Processing subset:  metaclip
# loading annotations into memory...
# Done (t=0.26s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.57s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.20s)
# creating index...
# index created!
# WARNING: 153 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.608
#  Average precision  @[ IoU=0.50:0.95] = 0.594
#  Average recall     @[ IoU=0.50:0.95] = 0.529
#  Average F1         @[ IoU=0.50:0.95] = 0.560
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.751
#  Average IL_precision                = 0.914
#  Average IL_recall                   = 0.768
#  Average IL_F1                       = 0.835
#  Average IL_FPR                      = 0.014
#  Average IL_MCC                      = 0.810
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.409
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.986
#  Average CGF1       @[ IoU=0.50     ] = 0.704
#  Average precision  @[ IoU=0.50     ] = 0.724
#  Average recall     @[ IoU=0.50     ] = 0.645
#  Average F1         @[ IoU=0.50     ] = 0.682
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.869
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.478
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.986
#  Average CGF1       @[ IoU=0.75     ] = 0.652
#  Average precision  @[ IoU=0.75     ] = 0.648
#  Average recall     @[ IoU=0.75     ] = 0.577
#  Average F1         @[ IoU=0.75     ] = 0.610
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.805
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.438
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.986
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.468
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.637
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.578
#  Average CGF1_micro @[ IoU=0.50     ] = 0.570
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.775
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.704
#  Average CGF1_micro @[ IoU=0.75     ] = 0.510
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.694
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.630
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.467
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.576
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.541
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.667
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.501
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.618
# Processing subset:  sa1b
# loading annotations into memory...
# Done (t=0.42s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.37s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.37s)
# creating index...
# index created!
# WARNING: 170 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.640
#  Average precision  @[ IoU=0.50:0.95] = 0.603
#  Average recall     @[ IoU=0.50:0.95] = 0.614
#  Average F1         @[ IoU=0.50:0.95] = 0.608
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.740
#  Average IL_precision                = 0.958
#  Average IL_recall                   = 0.925
#  Average IL_F1                       = 0.941
#  Average IL_FPR                      = 0.055
#  Average IL_MCC                      = 0.866
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.466
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.945
#  Average CGF1       @[ IoU=0.50     ] = 0.746
#  Average precision  @[ IoU=0.50     ] = 0.753
#  Average recall     @[ IoU=0.50     ] = 0.766
#  Average F1         @[ IoU=0.50     ] = 0.760
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.862
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.543
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.945
#  Average CGF1       @[ IoU=0.75     ] = 0.687
#  Average precision  @[ IoU=0.75     ] = 0.658
#  Average recall     @[ IoU=0.75     ] = 0.669
#  Average F1         @[ IoU=0.75     ] = 0.663
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.794
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.499
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.945
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.532
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.617
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.615
#  Average CGF1_micro @[ IoU=0.50     ] = 0.665
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.770
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.768
#  Average CGF1_micro @[ IoU=0.75     ] = 0.581
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.672
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.671
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.592
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.684
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.690
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.798
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.636
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.735
# Processing subset:  crowded
# loading annotations into memory...
# Done (t=0.39s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.36s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.38s)
# creating index...
# index created!
# WARNING: 218 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.613
#  Average precision  @[ IoU=0.50:0.95] = 0.635
#  Average recall     @[ IoU=0.50:0.95] = 0.679
#  Average F1         @[ IoU=0.50:0.95] = 0.656
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.680
#  Average IL_precision                = 0.930
#  Average IL_recall                   = 0.917
#  Average IL_F1                       = 0.923
#  Average IL_FPR                      = 0.020
#  Average IL_MCC                      = 0.901
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.245
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.980
#  Average CGF1       @[ IoU=0.50     ] = 0.743
#  Average precision  @[ IoU=0.50     ] = 0.770
#  Average recall     @[ IoU=0.50     ] = 0.824
#  Average F1         @[ IoU=0.50     ] = 0.796
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.825
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.317
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.980
#  Average CGF1       @[ IoU=0.75     ] = 0.668
#  Average precision  @[ IoU=0.75     ] = 0.695
#  Average recall     @[ IoU=0.75     ] = 0.743
#  Average F1         @[ IoU=0.75     ] = 0.718
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.741
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.266
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.980
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.605
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.663
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.671
#  Average CGF1_micro @[ IoU=0.50     ] = 0.733
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.804
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.814
#  Average CGF1_micro @[ IoU=0.75     ] = 0.662
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.726
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.734
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.562
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.623
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.681
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.756
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.612
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.679
# Processing subset:  fg_food
# loading annotations into memory...
# Done (t=0.11s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
# WARNING: 80 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.644
#  Average precision  @[ IoU=0.50:0.95] = 0.714
#  Average recall     @[ IoU=0.50:0.95] = 0.550
#  Average F1         @[ IoU=0.50:0.95] = 0.622
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.805
#  Average IL_precision                = 0.921
#  Average IL_recall                   = 0.722
#  Average IL_F1                       = 0.809
#  Average IL_FPR                      = 0.006
#  Average IL_MCC                      = 0.800
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.370
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.994
#  Average CGF1       @[ IoU=0.50     ] = 0.697
#  Average precision  @[ IoU=0.50     ] = 0.795
#  Average recall     @[ IoU=0.50     ] = 0.613
#  Average F1         @[ IoU=0.50     ] = 0.692
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.871
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.404
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.994
#  Average CGF1       @[ IoU=0.75     ] = 0.670
#  Average precision  @[ IoU=0.75     ] = 0.758
#  Average recall     @[ IoU=0.75     ] = 0.584
#  Average F1         @[ IoU=0.75     ] = 0.660
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.838
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.391
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.994
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.511
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.762
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.639
#  Average CGF1_micro @[ IoU=0.50     ] = 0.569
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.849
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.712
#  Average CGF1_micro @[ IoU=0.75     ] = 0.542
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.808
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.678
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.465
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.581
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.503
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.629
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.484
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.605
# Processing subset:  fg_sports_equipment
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.08s)
# creating index...
# index created!
# WARNING: 30 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.749
#  Average precision  @[ IoU=0.50:0.95] = 0.721
#  Average recall     @[ IoU=0.50:0.95] = 0.718
#  Average F1         @[ IoU=0.50:0.95] = 0.720
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.833
#  Average IL_precision                = 0.953
#  Average IL_recall                   = 0.878
#  Average IL_F1                       = 0.914
#  Average IL_FPR                      = 0.008
#  Average IL_MCC                      = 0.900
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.593
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.992
#  Average CGF1       @[ IoU=0.50     ] = 0.827
#  Average precision  @[ IoU=0.50     ] = 0.820
#  Average recall     @[ IoU=0.50     ] = 0.817
#  Average F1         @[ IoU=0.50     ] = 0.818
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.919
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.658
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.992
#  Average CGF1       @[ IoU=0.75     ] = 0.787
#  Average precision  @[ IoU=0.75     ] = 0.772
#  Average recall     @[ IoU=0.75     ] = 0.769
#  Average F1         @[ IoU=0.75     ] = 0.770
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.875
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.622
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.992
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.668
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.768
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.742
#  Average CGF1_micro @[ IoU=0.50     ] = 0.759
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.873
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.844
#  Average CGF1_micro @[ IoU=0.75     ] = 0.715
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.822
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.795
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.658
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.731
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.726
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.807
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.691
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.768
# Processing subset:  attributes
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# WARNING: 10 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.664
#  Average precision  @[ IoU=0.50:0.95] = 0.632
#  Average recall     @[ IoU=0.50:0.95] = 0.664
#  Average F1         @[ IoU=0.50:0.95] = 0.648
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.864
#  Average IL_precision                = 0.800
#  Average IL_recall                   = 0.824
#  Average IL_F1                       = 0.812
#  Average IL_FPR                      = 0.048
#  Average IL_MCC                      = 0.768
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.631
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.952
#  Average CGF1       @[ IoU=0.50     ] = 0.709
#  Average precision  @[ IoU=0.50     ] = 0.694
#  Average recall     @[ IoU=0.50     ] = 0.729
#  Average F1         @[ IoU=0.50     ] = 0.711
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.923
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.674
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.952
#  Average CGF1       @[ IoU=0.75     ] = 0.676
#  Average precision  @[ IoU=0.75     ] = 0.656
#  Average recall     @[ IoU=0.75     ] = 0.689
#  Average F1         @[ IoU=0.75     ] = 0.672
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.881
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.643
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.952
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.544
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.759
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.708
#  Average CGF1_micro @[ IoU=0.50     ] = 0.597
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.833
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.778
#  Average CGF1_micro @[ IoU=0.75     ] = 0.564
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.788
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.735
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.547
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.712
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.584
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.761
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.557
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.726
# Processing subset:  wiki_common
# loading annotations into memory...
# Done (t=0.21s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.18s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.21s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.22s)
# creating index...
# index created!
# WARNING: 21 images were not predicted!
# Demo metric, IoU type=segm
#  Average CGF1       @[ IoU=0.50:0.95] = 0.567
#  Average precision  @[ IoU=0.50:0.95] = 0.667
#  Average recall     @[ IoU=0.50:0.95] = 0.526
#  Average F1         @[ IoU=0.50:0.95] = 0.588
#  Average positive_macro_F1 @[ IoU=0.50:0.95] = 0.803
#  Average IL_precision                = 0.823
#  Average IL_recall                   = 0.618
#  Average IL_F1                       = 0.706
#  Average IL_FPR                      = 0.004
#  Average IL_MCC                      = 0.706
#  Average IL_perfect_pos @[ IoU=0.50:0.95] = 0.397
#  Average IL_perfect_neg @[ IoU=0.50:0.95] = 0.996
#  Average CGF1       @[ IoU=0.50     ] = 0.640
#  Average precision  @[ IoU=0.50     ] = 0.768
#  Average recall     @[ IoU=0.50     ] = 0.605
#  Average F1         @[ IoU=0.50     ] = 0.677
#  Average positive_macro_F1 @[ IoU=0.50     ] = 0.907
#  Average IL_perfect_pos @[ IoU=0.50     ] = 0.452
#  Average IL_perfect_neg @[ IoU=0.50     ] = 0.996
#  Average CGF1       @[ IoU=0.75     ] = 0.589
#  Average precision  @[ IoU=0.75     ] = 0.710
#  Average recall     @[ IoU=0.75     ] = 0.559
#  Average F1         @[ IoU=0.75     ] = 0.626
#  Average positive_macro_F1 @[ IoU=0.75     ] = 0.835
#  Average IL_perfect_pos @[ IoU=0.75     ] = 0.414
#  Average IL_perfect_neg @[ IoU=0.75     ] = 0.996
#  Average J                           = 0.000
#  Average F                           = 0.000
#  Average J&F                         = 0.000
#  Average CGF1_micro @[ IoU=0.50:0.95] = 0.434
#  Average positive_micro_precision @[ IoU=0.50:0.95] = 0.742
#  Average positive_micro_F1 @[ IoU=0.50:0.95] = 0.616
#  Average CGF1_micro @[ IoU=0.50     ] = 0.500
#  Average positive_micro_precision @[ IoU=0.50     ] = 0.854
#  Average positive_micro_F1 @[ IoU=0.50     ] = 0.708
#  Average CGF1_micro @[ IoU=0.75     ] = 0.462
#  Average positive_micro_precision @[ IoU=0.75     ] = 0.789
#  Average positive_micro_F1 @[ IoU=0.75     ] = 0.655
#  Average CGF1_w0dt  @[ IoU=0.50:0.95] = 0.350
#  Average positive_w0dt_macro_F1 @[ IoU=0.50:0.95] = 0.496
#  Average CGF1_w0dt  @[ IoU=0.50     ] = 0.396
#  Average positive_w0dt_macro_F1 @[ IoU=0.50     ] = 0.561
#  Average CGF1_w0dt  @[ IoU=0.75     ] = 0.364
#  Average positive_w0dt_macro_F1 @[ IoU=0.75     ] = 0.516

# %%
print("Subset name, CG_F1, CG_F1_m, IL_MCC, pmF1, pmF1_m, demoF1")
print(results)
# Out:
# Subset name, CG_F1, CG_F1_m, IL_MCC, pmF1, pmF1_m, demoF1
# metaclip: 60.81,46.84,0.81,75.05,57.82,56.0
# sa1b: 64.01,53.24,0.87,73.95,61.51,60.85
# crowded: 61.28,60.48,0.9,68.02,67.13,65.64
# fg_food: 64.38,51.13,0.8,80.48,63.91,62.17
# fg_sports_equipment: 74.94,66.78,0.9,83.3,74.23,71.96
# attributes: 66.35,54.37,0.77,86.43,70.83,64.75
# wiki_common: 56.67,43.45,0.71,80.29,61.55,58.82
